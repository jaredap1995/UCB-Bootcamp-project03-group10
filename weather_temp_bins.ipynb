# %%
import pandas as pd
from pathlib import Path

# %%
joined_tables_rawdata = Path("back_end/joined_tables.csv")

# %%
joined_tables = pd.read_csv(joined_tables_rawdata)

# %%
joined_tables.head()
# Out:
#      id                 date  north_south_sum_broadway  north_bike_broadway  \
# 0   3.0  2019-01-01 02:00:00                       3.0                  1.0
# 1  12.0  2019-01-01 11:00:00                       2.0                  2.0
# 2  13.0  2019-01-01 12:00:00                       7.0                  5.0
# 3  15.0  2019-01-01 14:00:00                      15.0                  6.0
# 4  23.0  2019-01-01 22:00:00                       1.0                  1.0
#
#    south_bike_broadway location_name  id-2               date-2  \
# 0                  2.0      Broadway   3.0  2019-01-01 02:00:00
# 1                  0.0      Broadway  12.0  2019-01-01 11:00:00
# 2                  2.0      Broadway  13.0  2019-01-01 12:00:00
# 3                  9.0      Broadway  15.0  2019-01-01 14:00:00
# 4                  0.0      Broadway  23.0  2019-01-01 22:00:00
#
#    total_ped_and_bike_burke  pedestrian_south_burke  ...  east_bike_fremont  \
# 0                       1.0                     0.0  ...                1.0
# 1                     137.0                    28.0  ...               31.0
# 2                     104.0                    20.0  ...               31.0
# 3                     146.0                    18.0  ...               61.0
# 4                       3.0                     1.0  ...                1.0
#
#    west_bike_fremont  location_name-3      id-4               date-4  \
# 0               11.0          Fremont  138915.0  2019-01-01 02:00:00
# 1               11.0          Fremont  138924.0  2019-01-01 11:00:00
# 2               29.0          Fremont  138925.0  2019-01-01 12:00:00
# 3               52.0          Fremont  138927.0  2019-01-01 14:00:00
# 4                2.0          Fremont  138935.0  2019-01-01 22:00:00
#
#   temp_real_f  temp_feel_f  precipitation_inch  weathercode wind_speed
# 0        32.6         27.5                 0.0          1.0        1.9
# 1        36.5         32.1                 0.0          3.0        1.9
# 2        38.2         33.8                 0.0          2.0        0.9
# 3        39.7         35.5                 0.0          2.0        0.5
# 4        35.1         30.5                 0.0          2.0        1.4
#
# [5 rows x 27 columns]

# %%
dtype_before = type(joined_tables["temp_real_f"])
  
# converting to list
temp_list = joined_tables["temp_real_f"].tolist()
  
# storing dtype after operation
dtype_after = type("temp_real_f")
  
temp_list
# Out:
# [32.6,
#  36.5,
#  38.2,
#  39.7,
#  35.1,
#  31.4,
#  41.8,
#  43.7,
#  43.1,
#  42.6,
#  43.3,
#  46.0,
#  46.5,
#  46.7,
#  49.1,
#  49.7,
#  49.4,
#  48.5,
#  46.0,
#  45.8,
#  45.5,
#  49.0,
#  44.9,
#  37.7,
#  37.3,
#  47.9,
#  46.7,
#  42.2,
#  44.2,
#  42.8,
#  41.2,
#  39.5,
#  39.3,
#  39.1,
#  40.7,
#  38.6,
#  35.5,
#  36.4,
#  37.0,
#  39.0,
#  42.0,
#  42.9,
#  41.1,
#  35.5,
#  33.9,
#  33.6,
#  38.2,
#  36.8,
#  37.6,
#  40.7,
#  39.1,
#  39.6,
#  40.0,
#  42.8,
#  46.8,
#  44.5,
#  46.1,
#  51.0,
#  47.4,
#  46.0,
#  44.2,
#  40.5,
#  40.4,
#  40.6,
#  52.9,
#  50.4,
#  39.3,
#  35.2,
#  53.5,
#  47.3,
#  42.2,
#  40.4,
#  37.8,
#  37.3,
#  34.1,
#  33.4,
#  31.7,
#  43.4,
#  47.8,
#  40.5,
#  35.3,
#  30.0,
#  29.5,
#  48.9,
#  43.2,
#  30.5,
#  30.6,
#  29.6,
#  31.5,
#  43.0,
#  42.2,
#  38.4,
#  33.8,
#  33.0,
#  34.3,
#  38.0,
#  38.9,
#  45.8,
#  48.6,
#  44.0,
#  40.1,
#  40.6,
#  42.4,
#  39.1,
#  39.3,
#  39.3,
#  44.7,
#  48.1,
#  49.6,
#  46.7,
#  46.0,
#  44.7,
#  43.9,
#  43.4,
#  45.9,
#  49.9,
#  47.8,
#  44.3,
#  47.5,
#  48.5,
#  47.0,
#  42.4,
#  38.4,
#  38.4,
#  44.2,
#  41.8,
#  41.3,
#  36.8,
#  36.7,
#  40.9,
#  42.4,
#  44.8,
#  44.2,
#  39.5,
#  40.6,
#  41.1,
#  42.5,
#  42.2,
#  42.6,
#  42.8,
#  46.4,
#  48.3,
#  47.3,
#  45.7,
#  45.8,
#  44.9,
#  45.1,
#  44.1,
#  41.7,
#  42.9,
#  44.8,
#  45.9,
#  46.1,
#  45.2,
#  44.1,
#  40.3,
#  40.0,
#  44.0,
#  44.3,
#  41.9,
#  41.6,
#  37.6,
#  47.7,
#  47.7,
#  44.4,
#  37.8,
#  39.9,
#  39.3,
#  39.3,
#  47.6,
#  44.6,
#  31.7,
#  30.4,
#  43.6,
#  40.8,
#  36.7,
#  33.8,
#  28.8,
#  48.0,
#  44.7,
#  30.8,
#  30.5,
#  33.6,
#  44.9,
#  48.2,
#  48.5,
#  43.3,
#  38.6,
#  35.7,
#  47.6,
#  45.8,
#  45.4,
#  63.9,
#  72.8,
#  82.8,
#  75.9,
#  43.8,
#  42.3,
#  45.3,
#  46.5,
#  43.9,
#  43.4,
#  43.3,
#  40.6,
#  40.8,
#  37.2,
#  40.8,
#  41.0,
#  32.2,
#  29.9,
#  29.1,
#  26.0,
#  26.3,
#  26.9,
#  27.5,
#  25.6,
#  25.0,
#  19.9,
#  14.5,
#  29.2,
#  27.1,
#  21.3,
#  19.3,
#  32.9,
#  34.1,
#  20.3,
#  27.2,
#  31.4,
#  34.7,
#  31.6,
#  29.0,
#  27.7,
#  27.8,
#  26.3,
#  33.2,
#  33.2,
#  32.4,
#  31.1,
#  31.2,
#  31.1,
#  28.6,
#  27.8,
#  28.2,
#  30.2,
#  27.9,
#  19.7,
#  13.4,
#  13.0,
#  23.4,
#  28.1,
#  33.1,
#  31.1,
#  30.8,
#  31.5,
#  27.4,
#  25.8,
#  33.6,
#  33.1,
#  33.8,
#  34.2,
#  32.8,
#  33.2,
#  32.9,
#  28.8,
#  27.8,
#  27.1,
#  25.5,
#  36.6,
#  36.0,
#  33.6,
#  36.2,
#  36.4,
#  33.6,
#  35.0,
#  39.7,
#  38.3,
#  33.4,
#  29.5,
#  37.8,
#  33.5,
#  37.1,
#  34.9,
#  30.0,
#  34.9,
#  39.0,
#  30.3,
#  36.6,
#  33.5,
#  34.5,
#  34.5,
#  34.3,
#  34.1,
#  34.4,
#  40.5,
#  35.7,
#  35.0,
#  38.9,
#  33.7,
#  33.2,
#  33.4,
#  34.8,
#  42.0,
#  33.0,
#  28.7,
#  33.8,
#  35.7,
#  36.7,
#  34.1,
#  32.9,
#  32.9,
#  33.8,
#  41.7,
#  43.0,
#  39.0,
#  28.4,
#  30.4,
#  37.8,
#  38.8,
#  39.9,
#  36.6,
#  30.1,
#  26.5,
#  31.3,
#  41.1,
#  39.8,
#  33.2,
#  30.1,
#  30.6,
#  30.2,
#  28.2,
#  38.6,
#  39.3,
#  31.3,
#  29.5,
#  27.8,
#  26.9,
#  31.3,
#  32.4,
#  34.0,
#  31.5,
#  28.7,
#  27.6,
#  36.7,
#  39.8,
#  68.1,
#  66.7,
#  65.6,
#  64.9,
#  71.2,
#  64.5,
#  64.4,
#  35.8,
#  35.4,
#  38.6,
#  44.3,
#  44.7,
#  42.2,
#  36.8,
#  34.3,
#  32.6,
#  33.8,
#  43.9,
#  26.8,
#  25.1,
#  36.2,
#  41.0,
#  43.0,
#  43.1,
#  33.7,
#  27.8,
#  26.4,
#  24.0,
#  23.2,
#  38.1,
#  34.2,
#  28.8,
#  27.0,
#  27.8,
#  33.6,
#  41.3,
#  44.9,
#  45.7,
#  43.7,
#  29.1,
#  27.8,
#  27.5,
#  27.5,
#  27.4,
#  33.6,
#  33.8,
#  30.7,
#  32.4,
#  42.6,
#  43.0,
#  42.1,
#  37.1,
#  34.7,
#  28.8,
#  29.6,
#  29.4,
#  36.4,
#  41.4,
#  41.0,
#  40.4,
#  34.1,
#  35.1,
#  43.8,
#  44.0,
#  44.1,
#  43.6,
#  30.9,
#  30.6,
#  31.4,
#  48.5,
#  48.4,
#  29.6,
#  48.7,
#  49.4,
#  49.4,
#  44.5,
#  37.5,
#  34.4,
#  43.1,
#  37.6,
#  33.3,
#  46.2,
#  37.1,
#  36.3,
#  36.8,
#  37.1,
#  35.9,
#  48.6,
#  50.7,
#  45.7,
#  39.4,
#  41.3,
#  40.9,
#  46.5,
#  55.3,
#  56.2,
#  51.1,
#  42.9,
#  40.7,
#  39.1,
#  37.7,
#  36.7,
#  50.3,
#  56.2,
#  47.3,
#  41.8,
#  37.5,
#  36.2,
#  56.9,
#  60.6,
#  60.0,
#  42.2,
#  34.5,
#  49.1,
#  55.2,
#  67.8,
#  51.9,
#  48.4,
#  35.6,
#  36.9,
#  43.2,
#  68.7,
#  65.6,
#  53.7,
#  38.2,
#  50.9,
#  63.0,
#  70.3,
#  69.6,
#  47.6,
#  43.2,
#  39.7,
#  55.5,
#  58.4,
#  55.0,
#  46.4,
#  43.4,
#  54.8,
#  53.7,
#  52.0,
#  51.2,
#  48.8,
#  47.3,
#  46.7,
#  41.4,
#  44.9,
#  50.4,
#  55.4,
#  54.8,
#  52.9,
#  47.1,
#  46.8,
#  44.9,
#  48.1,
#  52.8,
#  37.0,
#  35.7,
#  38.7,
#  56.8,
#  45.2,
#  43.4,
#  43.5,
#  43.6,
#  43.3,
#  43.1,
#  41.9,
#  43.1,
#  46.7,
#  50.3,
#  38.1,
#  56.6,
#  57.9,
#  46.7,
#  40.9,
#  38.5,
#  50.6,
#  54.8,
#  51.7,
#  46.7,
#  42.7,
#  38.4,
#  36.4,
#  38.5,
#  56.6,
#  57.8,
#  57.9,
#  51.4,
#  37.5,
#  36.8,
#  61.4,
#  45.3,
#  44.2,
#  43.5,
#  44.3,
#  49.2,
#  58.6,
#  60.2,
#  61.2,
#  75.5,
#  40.9,
#  40.0,
#  39.7,
#  60.6,
#  61.1,
#  43.2,
#  42.2,
#  42.6,
#  62.5,
#  64.3,
#  59.7,
#  57.9,
#  49.6,
#  50.3,
#  53.0,
#  54.8,
#  49.1,
#  47.6,
#  45.1,
#  41.3,
#  50.7,
#  59.5,
#  52.0,
#  50.3,
#  48.3,
#  53.6,
#  57.8,
#  48.9,
#  44.9,
#  43.5,
#  45.8,
#  53.1,
#  52.0,
#  50.2,
#  47.0,
#  45.9,
#  45.2,
#  44.7,
#  44.2,
#  43.8,
#  43.6,
#  49.4,
#  53.8,
#  54.8,
#  47.6,
#  44.7,
#  44.7,
#  53.3,
#  54.3,
#  55.6,
#  52.1,
#  48.5,
#  48.0,
#  45.8,
#  45.4,
#  44.7,
#  51.7,
#  54.9,
#  55.1,
#  49.3,
#  42.5,
#  43.8,
#  47.9,
#  44.3,
#  43.1,
#  43.4,
#  48.4,
#  48.5,
#  46.1,
#  45.1,
#  45.8,
#  45.8,
#  46.1,
#  46.4,
#  47.3,
#  49.9,
#  52.6,
#  53.6,
#  53.4,
#  47.0,
#  46.7,
#  44.4,
#  44.6,
#  47.4,
#  44.9,
#  42.1,
#  42.1,
#  42.4,
#  41.6,
#  43.1,
#  44.9,
#  49.4,
#  41.3,
#  38.6,
#  44.1,
#  48.8,
#  51.1,
#  52.6,
#  53.1,
#  53.8,
#  49.2,
#  42.2,
#  40.7,
#  41.0,
#  44.9,
#  51.0,
#  54.8,
#  54.0,
#  50.8,
#  48.5,
#  46.6,
#  57.0,
#  51.5,
#  52.4,
#  54.8,
#  54.0,
#  55.7,
#  57.4,
#  59.1,
#  60.4,
#  53.4,
#  50.4,
#  49.8,
#  53.0,
#  54.4,
#  51.1,
#  49.2,
#  47.7,
#  47.4,
#  47.2,
#  45.8,
#  45.5,
#  52.1,
#  53.9,
#  56.4,
#  57.0,
#  56.7,
#  47.4,
#  41.3,
#  55.2,
#  58.3,
#  51.8,
#  48.7,
#  41.8,
#  50.9,
#  49.2,
#  48.0,
#  47.7,
#  47.7,
#  48.7,
#  48.7,
#  49.2,
#  50.1,
#  52.6,
#  56.5,
#  58.1,
#  56.2,
#  52.2,
#  45.8,
#  45.2,
#  44.1,
#  51.7,
#  51.2,
#  48.4,
#  39.4,
#  38.1,
#  36.5,
#  54.1,
#  56.2,
#  57.3,
#  54.3,
#  53.0,
#  46.9,
#  46.0,
#  45.3,
#  41.5,
#  60.0,
#  60.7,
#  55.9,
#  52.9,
#  47.5,
#  44.1,
#  43.5,
#  42.2,
#  42.6,
#  41.0,
#  38.4,
#  55.7,
#  56.8,
#  50.7,
#  48.1,
#  42.2,
#  40.4,
#  38.6,
#  58.4,
#  41.0,
#  39.8,
#  52.3,
#  61.8,
#  58.0,
#  55.3,
#  44.0,
#  66.2,
#  64.2,
#  57.6,
#  68.7,
#  75.5,
#  81.7,
#  83.7,
#  74.2,
#  71.5,
#  64.0,
#  60.5,
#  61.4,
#  72.5,
#  42.3,
#  41.3,
#  47.5,
#  55.4,
#  61.4,
#  59.5,
#  57.5,
#  45.2,
#  46.4,
#  48.2,
#  54.6,
#  52.4,
#  49.9,
#  46.9,
#  44.7,
#  52.3,
#  44.0,
#  45.6,
#  50.1,
#  53.3,
#  57.9,
#  62.2,
#  53.8,
#  49.9,
#  48.5,
#  48.1,
#  56.5,
#  61.3,
#  62.6,
#  56.4,
#  53.5,
#  53.6,
#  47.9,
#  48.1,
#  65.6,
#  69.7,
#  67.4,
#  65.5,
#  55.1,
#  53.9,
#  65.3,
#  55.4,
#  51.3,
#  49.2,
#  65.1,
#  68.4,
#  63.8,
#  51.1,
#  73.2,
#  73.8,
#  67.5,
#  60.1,
#  50.2,
#  64.6,
#  72.3,
#  77.4,
#  78.9,
#  78.4,
#  71.3,
#  54.9,
#  67.2,
#  73.7,
#  50.4,
#  56.8,
#  59.3,
#  63.1,
#  65.8,
#  51.3,
#  47.9,
#  54.7,
#  63.2,
#  63.9,
#  55.0,
#  53.5,
#  51.2,
#  52.5,
#  52.0,
#  51.2,
#  59.1,
#  56.5,
#  51.2,
#  48.0,
#  58.1,
#  60.6,
#  64.4,
#  60.1,
#  56.0,
#  50.7,
#  47.1,
#  58.4,
#  59.0,
#  60.1,
#  59.3,
#  58.7,
#  55.7,
#  53.3,
#  52.7,
#  51.2,
#  50.6,
#  51.0,
#  57.3,
#  60.3,
#  59.4,
#  53.7,
#  52.5,
#  50.0,
#  54.2,
#  56.0,
#  63.3,
#  65.0,
#  66.4,
#  55.3,
#  55.7,
#  61.7,
#  64.6,
#  54.2,
#  55.3,
#  47.6,
#  47.4,
#  50.9,
#  54.0,
#  55.3,
#  57.3,
#  60.4,
#  62.4,
#  63.1,
#  62.5,
#  56.2,
#  47.6,
#  60.8,
#  65.4,
#  63.0,
#  61.9,
#  50.2,
#  73.1,
#  56.9,
#  53.3,
#  52.3,
#  51.6,
#  53.4,
#  53.9,
#  61.2,
#  63.3,
#  67.7,
#  66.5,
#  60.2,
#  51.4,
#  64.1,
#  67.0,
#  69.7,
#  73.1,
#  71.9,
#  52.0,
#  52.5,
#  66.8,
#  68.6,
#  69.3,
#  63.8,
#  60.1,
#  55.9,
#  51.1,
#  55.1,
#  61.1,
#  59.3,
#  55.1,
#  66.3,
#  70.8,
#  62.5,
#  58.6,
#  58.4,
#  54.1,
#  61.0,
#  69.1,
#  70.5,
#  74.2,
#  75.5,
#  75.9,
#  59.8,
#  55.0,
#  71.9,
#  73.7,
#  72.8,
#  71.0,
#  64.8,
#  62.6,
#  59.0,
#  61.3,
#  72.1,
#  73.9,
#  74.5,
#  71.4,
#  68.5,
#  57.5,
#  54.4,
#  52.7,
#  58.8,
#  60.5,
#  62.5,
#  63.3,
#  60.7,
#  57.8,
#  53.9,
#  52.1,
#  53.9,
#  67.9,
#  54.1,
#  56.0,
#  50.1,
#  51.2,
#  56.6,
#  57.3,
#  48.5,
#  48.5,
#  53.6,
#  57.7,
#  50.7,
#  50.1,
#  49.5,
#  49.8,
#  62.2,
#  63.9,
#  62.9,
#  56.3,
#  52.7,
#  62.0,
#  66.4,
#  63.0,
#  61.3,
#  51.3,
#  51.1,
#  72.8,
#  71.0,
#  60.1,
#  56.1,
#  78.8,
#  62.2,
#  57.7,
#  62.0,
#  77.9,
#  86.3,
#  71.5,
#  72.3,
#  ...]

# %%
joined_tables_df = pd.DataFrame(joined_tables)
joined_tables_df.head()
# Out:
#      id                 date  north_south_sum_broadway  north_bike_broadway  \
# 0   3.0  2019-01-01 02:00:00                       3.0                  1.0
# 1  12.0  2019-01-01 11:00:00                       2.0                  2.0
# 2  13.0  2019-01-01 12:00:00                       7.0                  5.0
# 3  15.0  2019-01-01 14:00:00                      15.0                  6.0
# 4  23.0  2019-01-01 22:00:00                       1.0                  1.0
#
#    south_bike_broadway location_name  id-2               date-2  \
# 0                  2.0      Broadway   3.0  2019-01-01 02:00:00
# 1                  0.0      Broadway  12.0  2019-01-01 11:00:00
# 2                  2.0      Broadway  13.0  2019-01-01 12:00:00
# 3                  9.0      Broadway  15.0  2019-01-01 14:00:00
# 4                  0.0      Broadway  23.0  2019-01-01 22:00:00
#
#    total_ped_and_bike_burke  pedestrian_south_burke  ...  east_bike_fremont  \
# 0                       1.0                     0.0  ...                1.0
# 1                     137.0                    28.0  ...               31.0
# 2                     104.0                    20.0  ...               31.0
# 3                     146.0                    18.0  ...               61.0
# 4                       3.0                     1.0  ...                1.0
#
#    west_bike_fremont  location_name-3      id-4               date-4  \
# 0               11.0          Fremont  138915.0  2019-01-01 02:00:00
# 1               11.0          Fremont  138924.0  2019-01-01 11:00:00
# 2               29.0          Fremont  138925.0  2019-01-01 12:00:00
# 3               52.0          Fremont  138927.0  2019-01-01 14:00:00
# 4                2.0          Fremont  138935.0  2019-01-01 22:00:00
#
#   temp_real_f  temp_feel_f  precipitation_inch  weathercode wind_speed
# 0        32.6         27.5                 0.0          1.0        1.9
# 1        36.5         32.1                 0.0          3.0        1.9
# 2        38.2         33.8                 0.0          2.0        0.9
# 3        39.7         35.5                 0.0          2.0        0.5
# 4        35.1         30.5                 0.0          2.0        1.4
#
# [5 rows x 27 columns]

# %%
sorted_version_desc = joined_tables_df.sort_values(by='temp_real_f', ascending=False)
sorted_version_desc.head()
# Out:
#        id date  north_south_sum_broadway  north_bike_broadway  \
# 58203 NaN  NaN                       NaN                  NaN
# 41807 NaN  NaN                       NaN                  NaN
# 23757 NaN  NaN                       NaN                  NaN
# 24216 NaN  NaN                       NaN                  NaN
# 57861 NaN  NaN                       NaN                  NaN
#
#        south_bike_broadway location_name  id-2 date-2  \
# 58203                  NaN           NaN   NaN    NaN
# 41807                  NaN           NaN   NaN    NaN
# 23757                  NaN           NaN   NaN    NaN
# 24216                  NaN           NaN   NaN    NaN
# 57861                  NaN           NaN   NaN    NaN
#
#        total_ped_and_bike_burke  pedestrian_south_burke  ...  \
# 58203                       NaN                     NaN  ...
# 41807                       NaN                     NaN  ...
# 23757                       NaN                     NaN  ...
# 24216                       NaN                     NaN  ...
# 57861                       NaN                     NaN  ...
#
#        east_bike_fremont  west_bike_fremont  location_name-3      id-4  \
# 58203               26.0               55.0          Fremont  160745.0
# 41807               21.0               34.0          Fremont  160744.0
# 23757               21.0               61.0          Fremont  160746.0
# 24216               17.0               28.0          Fremont  160743.0
# 57861               25.0               59.0          Fremont  160747.0
#
#                     date-4 temp_real_f  temp_feel_f  precipitation_inch  \
# 58203  2021-06-28 16:00:00       106.0        111.1                 0.0
# 41807  2021-06-28 15:00:00       105.8        111.8                 0.0
# 23757  2021-06-28 17:00:00       104.9        108.5                 0.0
# 24216  2021-06-28 14:00:00       104.6        110.8                 0.0
# 57861  2021-06-28 18:00:00       102.7        105.2                 0.0
#
#        weathercode wind_speed
# 58203          0.0        4.5
# 41807          0.0        4.8
# 23757          0.0        5.4
# 24216          0.0        5.9
# 57861          0.0        5.9
#
# [5 rows x 27 columns]

# %%
sorted_version_asc = joined_tables_df.sort_values(by='temp_real_f', ascending=True)
sorted_version_asc.head()
# Out:
#        id date  north_south_sum_broadway  north_bike_broadway  \
# 25431 NaN  NaN                       NaN                  NaN
# 60322 NaN  NaN                       NaN                  NaN
# 60323 NaN  NaN                       NaN                  NaN
# 25430 NaN  NaN                       NaN                  NaN
# 42974 NaN  NaN                       NaN                  NaN
#
#        south_bike_broadway location_name   id-2               date-2  \
# 25431                  NaN           NaN  991.0  2019-02-10 07:00:00
# 60322                  NaN           NaN  992.0  2019-02-10 08:00:00
# 60323                  NaN           NaN  993.0  2019-02-10 09:00:00
# 25430                  NaN           NaN  990.0  2019-02-10 06:00:00
# 42974                  NaN           NaN  989.0  2019-02-10 05:00:00
#
#        total_ped_and_bike_burke  pedestrian_south_burke  ...  \
# 25431                       3.0                     3.0  ...
# 60322                       7.0                     3.0  ...
# 60323                      18.0                     8.0  ...
# 25430                       0.0                     0.0  ...
# 42974                       0.0                     0.0  ...
#
#        east_bike_fremont  west_bike_fremont  location_name-3      id-4  \
# 25431                0.0                0.0          Fremont  139880.0
# 60322                2.0                0.0          Fremont  139881.0
# 60323                0.0                0.0          Fremont  139882.0
# 25430                0.0                0.0          Fremont  139879.0
# 42974                1.0                0.0          Fremont  139878.0
#
#                     date-4 temp_real_f  temp_feel_f  precipitation_inch  \
# 25431  2019-02-10 07:00:00         8.1         -0.1                 0.0
# 60322  2019-02-10 08:00:00         8.8          0.1                 0.0
# 60323  2019-02-10 09:00:00         9.8          1.2                 0.0
# 25430  2019-02-10 06:00:00        10.4          2.1                 0.0
# 42974  2019-02-10 05:00:00        12.5          4.0                 0.0
#
#        weathercode wind_speed
# 25431          1.0        4.0
# 60322          1.0        5.0
# 60323          1.0        4.9
# 25430          0.0        4.2
# 42974          0.0        5.0
#
# [5 rows x 27 columns]

# %%
bins = [0, 30, 50, 70, 90, 110]

# Create the names for the five bins
group_names = ["0-30F", "31-50F", "51-70F", "71-90", "91-110"]

# %%
bins_data = joined_tables_df["temp_real_f"] = pd.cut(joined_tables_df["temp_real_f"], bins, labels=group_names, include_lowest=True)
bins_data
# Out:
# 0        31-50F
# 1        31-50F
# 2        31-50F
# 3        31-50F
# 4        31-50F
#           ...
# 77371    51-70F
# 77372    31-50F
# 77373    31-50F
# 77374    31-50F
# 77375    31-50F
# Name: temp_real_f, Length: 77376, dtype: category
# Categories (5, object): ['0-30F' < '31-50F' < '51-70F' < '71-90' < '91-110']

# %%
group_df = joined_tables_df.groupby("temp_real_f")
group_df.max()
# Out:
# C:\Users\karin\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#                   id  north_south_sum_broadway  north_bike_broadway  \
# temp_real_f
# 0-30F        63539.0                      42.0                 20.0
# 31-50F       63552.0                      78.0                 54.0
# 51-70F       63277.0                     112.0                 99.0
# 71-90        61290.0                      97.0                 71.0
# 91-110       60067.0                      64.0                 34.0
#
#              south_bike_broadway     id-2  total_ped_and_bike_burke  \
# temp_real_f
# 0-30F                       29.0  67595.0                     144.0
# 31-50F                      46.0  67608.0                    9213.0
# 51-70F                      61.0  67333.0                   10493.0
# 71-90                       54.0  65346.0                    4055.0
# 91-110                      35.0  64123.0                     634.0
#
#              pedestrian_south_burke  pedestrian_north_burke  bike_north_burke  \
# temp_real_f
# 0-30F                          64.0                    58.0              60.0
# 31-50F                       2655.0                  4095.0             217.0
# 51-70F                       3646.0                  1621.0             794.0
# 71-90                        4054.0                   788.0             476.0
# 91-110                        505.0                   109.0             112.0
#
#              bike_south_burke  ...  east_west_sum_fremont east_bike_fremont  \
# temp_real_f                    ...
# 0-30F                    55.0  ...                  644.0             347.0
# 31-50F                 4095.0  ...                  869.0             537.0
# 51-70F                 8191.0  ...                 1004.0             698.0
# 71-90                   419.0  ...                 1097.0             541.0
# 91-110                  143.0  ...                  814.0             192.0
#
#              west_bike_fremont  location_name-3      id-4  \
# temp_real_f
# 0-30F                    358.0          Fremont  158720.0
# 31-50F                   652.0          Fremont  163728.0
# 51-70F                   768.0          Fremont  163722.0
# 71-90                    850.0          Fremont  162883.0
# 91-110                   622.0          Fremont  161851.0
#
#                           date-4  temp_feel_f precipitation_inch  weathercode  \
# temp_real_f
# 0-30F        2021-04-05 07:00:00         25.1              0.051         75.0
# 31-50F       2021-10-30 23:00:00         49.3              0.205         75.0
# 51-70F       2021-10-30 17:00:00         74.6              0.252         63.0
# 71-90        2021-09-25 18:00:00         95.9              0.063         61.0
# 91-110       2021-08-13 18:00:00        111.8              0.000          2.0
#
#              wind_speed
# temp_real_f
# 0-30F              12.3
# 31-50F             23.9
# 51-70F             26.2
# 71-90              16.0
# 91-110              9.2
#
# [5 rows x 22 columns]
